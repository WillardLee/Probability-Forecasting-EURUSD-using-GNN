# %% [markdown]
# <a href="https://colab.research.google.com/github/WillardLee/Probability-Forecasting-EURUSD-using-GNN/blob/main/ip2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/IP2')

# %%
import pandas as pd
csv_path = '/content/drive/MyDrive/IP2/EURUSD_daily.csv'
df = pd.read_csv(csv_path)
# Out:
#        <DATE>   <OPEN>   <HIGH>    <LOW>  <CLOSE>
# 0  2014.01.01  1.37550  1.37648  1.37372  1.37580
# 1  2014.01.02  1.37581  1.37749  1.36294  1.36643
# 2  2014.01.03  1.36643  1.36716  1.35821  1.35874
# 3  2014.01.06  1.35955  1.36528  1.35712  1.36334
# 4  2014.01.07  1.36334  1.36562  1.35966  1.36138
